# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.head()
# Out:
#    Opening  Opening.1              Title  \
# 0  JANUARY          3         The Grudge
# 1  JANUARY         10         Underwater
# 2  JANUARY         10        Like a Boss
# 3  JANUARY         10      Three Christs
# 4  JANUARY         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                                 Paramount Pictures
# 3                                          IFC Films
# 4     Barry Films / Tycor International Film Company
#
#                                        Cast and crew Ref.
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...  [2]
# 1  William Eubank (director); Brian Duffield, Ada...  [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...  [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...  NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...  [5]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [269 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\programdata\anaconda3\lib\site-packages (1.7.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from tmdbv3api) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.0.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '9e233bf3d8f1f88d4f47e743ac958cc0'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-32-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Drama Thriller Crime
# ..                                      ...
# 264      Action Fantasy Family Drama Comedy
# 265          Action Adventure Drama Western
# 266                                   Drama
# 267                    Thriller Crime Drama
# 268                                   Drama
#
# [269 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in (x):
        return x.split("(director)")[0]
    elif " (directors)" in x:
        return x.split("(directors)")[0]
    else:
        return x.split("(director/screenplay)")[0]

# %%
df_2020["director_name"]= df_2020["Cast and crew"].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-38-879a14c2a9bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020["director_name"]= df_2020["Cast and crew"].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return((x.split("screenplay); ")[-1]).split(",")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x:get_actor1(str(x)))
# Out:
# <ipython-input-40-391b8a494c08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x:get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(",")) <2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(",")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(",")) <3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(",")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 267  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres      director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Drama Thriller Crime    Anthony Jerjen
# ..                                      ...                ...
# 264      Action Fantasy Family Drama Comedy  Robert Rodriguez
# 265          Action Adventure Drama Western   Paul Greengrass
# 266                                   Drama       Regina King
# 267                    Thriller Crime Drama   Emerald Fennell
# 268                                   Drama  Kornél Mundruczó
#
#               actor_1_name        actor_2_name      actor_3_name
# 0       Andrea Riseborough       Demián Bichir          John Cho
# 1          Kristen Stewart      Vincent Cassel   Jessica Henwick
# 2          Tiffany Haddish          Rose Byrne       Salma Hayek
# 3             Richard Gere      Peter Dinklage    Walton Goggins
# 4            Josh Hartnett   Margarita Levieva    Chandler Riggs
# ..                     ...                 ...               ...
# 264  Priyanka Chopra Jonas        Pedro Pascal     YaYa Gosselin
# 265              Tom Hanks       Helena Zengel               NaN
# 266      Kingsley Ben-Adir           Eli Goree       Aldis Hodge
# 267         Carey Mulligan          Bo Burnham       Alison Brie
# 268          Vanessa Kirby        Shia LaBeouf      Molly Parker
#
# [269 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#          director_name           actor_1_name        actor_2_name  \
# 0       Nicolas Pesce      Andrea Riseborough       Demián Bichir
# 1      William Eubank         Kristen Stewart      Vincent Cassel
# 2       Miguel Arteta         Tiffany Haddish          Rose Byrne
# 3           Jon Avnet            Richard Gere      Peter Dinklage
# 4      Anthony Jerjen           Josh Hartnett   Margarita Levieva
# ..                 ...                    ...                 ...
# 264  Robert Rodriguez   Priyanka Chopra Jonas        Pedro Pascal
# 265   Paul Greengrass               Tom Hanks       Helena Zengel
# 266       Regina King       Kingsley Ben-Adir           Eli Goree
# 267   Emerald Fennell          Carey Mulligan          Bo Burnham
# 268  Kornél Mundruczó           Vanessa Kirby        Shia LaBeouf
#
#          actor_3_name                                  genres  \
# 0            John Cho                 Horror Mystery Thriller
# 1     Jessica Henwick  Action Horror Science Fiction Thriller
# 2         Salma Hayek                                  Comedy
# 3      Walton Goggins                                   Drama
# 4      Chandler Riggs                    Drama Thriller Crime
# ..                ...                                     ...
# 264     YaYa Gosselin      Action Fantasy Family Drama Comedy
# 265               NaN          Action Adventure Drama Western
# 266       Aldis Hodge                                   Drama
# 267       Alison Brie                    Thriller Crime Drama
# 268      Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 264       We Can Be Heroes
# 265      News of the World
# 266     One Night in Miami
# 267  Promising Young Woman
# 268      Pieces of a Woman
#
# [269 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' +new_df20['actor_2_name'] + ' ' + new_df20['actor_3_name'] +',' + new_df20['genres'] + ',' +new_df20['movie_title']

# %%
new_df20
# Out:
#          director_name           actor_1_name        actor_2_name  \
# 0       Nicolas Pesce      Andrea Riseborough       Demián Bichir
# 1      William Eubank         Kristen Stewart      Vincent Cassel
# 2       Miguel Arteta         Tiffany Haddish          Rose Byrne
# 3           Jon Avnet            Richard Gere      Peter Dinklage
# 4      Anthony Jerjen           Josh Hartnett   Margarita Levieva
# ..                 ...                    ...                 ...
# 264  Robert Rodriguez   Priyanka Chopra Jonas        Pedro Pascal
# 265   Paul Greengrass               Tom Hanks       Helena Zengel
# 266       Regina King       Kingsley Ben-Adir           Eli Goree
# 267   Emerald Fennell          Carey Mulligan          Bo Burnham
# 268  Kornél Mundruczó           Vanessa Kirby        Shia LaBeouf
#
#          actor_3_name                                  genres  \
# 0            John Cho                 Horror Mystery Thriller
# 1     Jessica Henwick  Action Horror Science Fiction Thriller
# 2         Salma Hayek                                  Comedy
# 3      Walton Goggins                                   Drama
# 4      Chandler Riggs                    Drama Thriller Crime
# ..                ...                                     ...
# 264     YaYa Gosselin      Action Fantasy Family Drama Comedy
# 265               NaN          Action Adventure Drama Western
# 266       Aldis Hodge                                   Drama
# 267       Alison Brie                    Thriller Crime Drama
# 268      Molly Parker                                   Drama
#
#                movie_title                                               comb
# 0               The Grudge  Andrea Riseborough  Demián Bichir  John Cho,Ho...
# 1               Underwater  Kristen Stewart  Vincent Cassel  Jessica Henwi...
# 2              Like a Boss  Tiffany Haddish  Rose Byrne  Salma Hayek,Comed...
# 3            Three Christs  Richard Gere  Peter Dinklage  Walton Goggins,D...
# 4        Inherit the Viper  Josh Hartnett  Margarita Levieva  Chandler Rig...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Priyanka Chopra Jonas  Pedro Pascal  YaYa Goss...
# 265      News of the World                                                NaN
# 266     One Night in Miami  Kingsley Ben-Adir  Eli Goree  Aldis Hodge,Dram...
# 267  Promising Young Woman  Carey Mulligan  Bo Burnham  Alison Brie,Thrill...
# 268      Pieces of a Woman  Vanessa Kirby  Shia LaBeouf  Molly Parker,Dram...
#
# [269 rows x 7 columns]

# %%
new_df20.isnull().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            1
# movie_title       0
# comb             27
# dtype: int64

# %%
new_df20 = new_df20.dropna(how = 'any')

# %%
new_df20.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-56-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#          director_name           actor_1_name        actor_2_name  \
# 0       Nicolas Pesce      Andrea Riseborough       Demián Bichir
# 1      William Eubank         Kristen Stewart      Vincent Cassel
# 2       Miguel Arteta         Tiffany Haddish          Rose Byrne
# 3           Jon Avnet            Richard Gere      Peter Dinklage
# 4      Anthony Jerjen           Josh Hartnett   Margarita Levieva
# ..                 ...                    ...                 ...
# 263       Pete Docter              Jamie Foxx            Tina Fey
# 264  Robert Rodriguez   Priyanka Chopra Jonas        Pedro Pascal
# 266       Regina King       Kingsley Ben-Adir           Eli Goree
# 267   Emerald Fennell          Carey Mulligan          Bo Burnham
# 268  Kornél Mundruczó           Vanessa Kirby        Shia LaBeouf
#
#          actor_3_name                                       genres  \
# 0            John Cho                      Horror Mystery Thriller
# 1     Jessica Henwick       Action Horror Science Fiction Thriller
# 2         Salma Hayek                                       Comedy
# 3      Walton Goggins                                        Drama
# 4      Chandler Riggs                         Drama Thriller Crime
# ..                ...                                          ...
# 263     Graham Norton  Family Animation Comedy Drama Music Fantasy
# 264     YaYa Gosselin           Action Fantasy Family Drama Comedy
# 266       Aldis Hodge                                        Drama
# 267       Alison Brie                         Thriller Crime Drama
# 268      Molly Parker                                        Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Risebor